# %% [markdown]
# # **SIMPLE NEURAL NETWORK LAB**
# With this notebook we are going to explore the basics about the hyper parameter tuning in a simple neural network with keras and tensowflow. To do so, we will use the fashion MNIST from keras that can be explored and get more info [here](https://github.com/zalandoresearch/fashion-mnist).

# %%
# General use
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Machine Learning
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten
from keras.optimizers import SGD
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# Let's define some methods that will be useful later when we present the results

# %%
def plot_acc(history, title="Model Accuracy"):
    '''
    Plot the accuracy per epoch got in the training
    '''
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(title)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
    
def plot_loss(history, title="Model Loss"):
  '''
  Plot the loss per epoch got in the training
  '''
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title(title)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()
    
def plot_compare_losses(history1, history2, name1="Red 1",
                        name2="Red 2", title="Graph title"):
  '''
  Compares two losses from two different trainings with name1 and name2
  '''
  plt.plot(history1.history['loss'], color="green")
  plt.plot(history1.history['val_loss'], 'r--', color="green")
  plt.plot(history2.history['loss'], color="blue")
  plt.plot(history2.history['val_loss'], 'r--', color="blue")
  plt.title(title)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train ' + name1, 'Val ' + name1, 
                'Train ' + name2, 'Val ' + name2],
               loc='upper right')
  plt.show()
    
def plot_compare_accs(history1, history2, name1="Red 1",
                      name2="Red 2", title="Graph title"):
  '''
  Compares two accuracies from two different trainings with name1 and nam2
  '''
  plt.plot(history1.history['acc'], color="green")
  plt.plot(history1.history['val_accuracy'], 'r--', color="green")
  plt.plot(history2.history['accuracy'], color="blue")
  plt.plot(history2.history['val_accuracy'], 'r--', color="blue")
  plt.title(title)
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train ' + name1, 'Val ' + name1, 
                'Train ' + name2, 'Val ' + name2], 
               loc='lower right')
  plt.show()


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='MATRIZ CONFUSIÓN',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Observación')
    plt.xlabel('Predicción')

# %% [markdown]
# ## **1. LOAD DATASET**
# We can download such dataset directly from [keras](https://www.kaggle.com/zalando-research/fashionmnist)

# %%
# We load the data directly from keras
(trainX, trainY), (testX, testY) = fashion_mnist.load_data()

# %% [markdown]
# # 1.1. Data Exploration

# %%
# We explore the data we got
print("Training: {}\nTest: {}".format(trainX.shape, testX.shape))

# Get also the clases, encoding it to categorical
trainY_cat = to_categorical(trainY)
testY_cat = to_categorical(testY)
print("\nClasses: {}".format(trainY_cat.shape))
# Out:
# Training: (60000, 28, 28)
# Test: (10000, 28, 28)
#
# Classes: (60000, 10)

# %%
# We map the clases for a better representation
class_names = {
0: 	'T-shirt/top',
1:	'Trouser',
2:	'Pullover',
3:	'Dress',
4: 	'Coat',
5:	'Sandal',
6:	'Shirt',
7:	'Sneaker',
8:	'Bag',
9:	'Ankle boot'
}

# %% [markdown]
# # 1.2 Data Preview

# %%
def plot_item(item):
  '''
  Displays just one item from the dataset
  '''
  plt.figure()
  plt.imshow(item)
  plt.show()


def plot_sample(size, dim = 5):
  '''
  Display a sub dataset from the original one
  '''
  plt.figure(figsize = (dim, dim))
  cols = size/dim
  for i in range (size):
    plt.subplot(dim, cols, i+1)
    plt.imshow(trainX[i])
  plt.show()


def plot_distribution():
  '''
  Plots the distribution of every class
  '''
  plt.figure(figsize = (10,6))
  fashion = list(class_names.values())
  # We user the raw data (no categorical) to count them up
  unique, count = np.unique(trainY, return_counts = True)

  plt.bar(fashion, count)
  plt.xlabel('fashion name')
  plt.ylabel('number')
  plt.show()

# %%
# Visualize just one item
plot_item(trainX[6])

# %%
# Visualize a subset from the original dataset spcifying the number of item
plot_sample(20)

# %%
# Let's see the distribution of the data
plot_distribution()

# %% [markdown]
# ##**2. THE MODEL**
# # 2.1 Define the architectures

# %% [markdown]
# ### 2.1.1 Model 1

# %%
# Define model n1
n_classes = trainY_cat.shape[1]
model1 = Sequential()
model1.add(Flatten(input_shape =(28,28) ))
model1.add(Dense(128, activation='sigmoid'))
model1.add(Dense (64, activation='sigmoid'))
model1.add(Dense(n_classes, activation='softmax'))

# %% [markdown]
# ### 2.1.2 Model 2

# %%
# Rehape the training data to have only one channel
trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
testX = testX.reshape((testX.shape[0], 28, 28, 1))

# MAke it easier te convergence 
trainX = trainX/255
testX = testX/255

# %%
# Define model n2
model2 = Sequential()
model2.add(Conv2D(32, (3,3), activation='relu', input_shape= trainX[1].shape ))
model2.add(MaxPooling2D(2,2))
model2.add(Flatten())
model2.add(Dense (64, activation='relu'))
model2.add(Dense(n_classes, activation = 'softmax'))

# %% [markdown]
# ### 2.1.3 Model 3

# %%
# Define model n3
model3 = Sequential()
model3.add(Conv2D(64, (3,3), activation='relu', input_shape= trainX[1].shape ))
model3.add(MaxPooling2D(pool_size=(2, 2)) )
# cnn 1
model3.add(Conv2D(64, (3,3)))
model3.add(keras.layers.BatchNormalization())
model3.add(keras.layers.Activation('softmax'))
# cnn 2
model3.add(Conv2D(64,3))
model3.add(keras.layers.BatchNormalization())
model3.add(keras.layers.Activation('softmax'))
# cnn 3
model3.add(Conv2D(32,3))
model3.add(keras.layers.BatchNormalization())
model3.add(keras.layers.Activation('softmax'))
model3.add(keras.layers.Dropout(0.25))
model3.add(Dense (64, activation='softmax'))
model3.add(Dense(n_classes, activation = 'softmax') )

# %% [markdown]
# # 2.2 Compilation

# %%
model1.compile(
    optimizer = 'sgd',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
model2.compile(
    optimizer = 'sgd',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
model3.compile(
    optimizer = 'sgd',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %% [markdown]
# ## 2.3 Fit

# %%
# Define number of epochs and batch size
epochs = 20
batch_size = 64

# Train the model 1
history1 = model1.fit(trainX, trainY_cat,
           epochs = epochs,
           batch_size = batch_size,
           validation_split = 0.2)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 2s 3ms/step - loss: 1.8032 - accuracy: 0.5546 - val_loss: 1.3855 - val_accuracy: 0.6834
# Epoch 2/20
# 750/750 [==============================] - 2s 2ms/step - loss: 1.1490 - accuracy: 0.7154 - val_loss: 0.9670 - val_accuracy: 0.7454
# Epoch 3/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.8695 - accuracy: 0.7581 - val_loss: 0.7916 - val_accuracy: 0.7663
# Epoch 4/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.7388 - accuracy: 0.7771 - val_loss: 0.6969 - val_accuracy: 0.7887
# Epoch 5/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.6648 - accuracy: 0.7917 - val_loss: 0.6413 - val_accuracy: 0.7930
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.6122 - accuracy: 0.8026 - val_loss: 0.5993 - val_accuracy: 0.7977
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5799 - accuracy: 0.8092 - val_loss: 0.5771 - val_accuracy: 0.8087
# Epoch 8/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5604 - accuracy: 0.8130 - val_loss: 0.5508 - val_accuracy: 0.8136
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.8167 - val_loss: 0.5358 - val_accuracy: 0.8222
# Epoch 10/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.8198 - val_loss: 0.5444 - val_accuracy: 0.8111
# Epoch 11/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5250 - accuracy: 0.8237 - val_loss: 0.5288 - val_accuracy: 0.8192
# Epoch 12/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5204 - accuracy: 0.8233 - val_loss: 0.5229 - val_accuracy: 0.8257
# Epoch 13/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5140 - accuracy: 0.8238 - val_loss: 0.5168 - val_accuracy: 0.8189
# Epoch 14/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5103 - accuracy: 0.8245 - val_loss: 0.5269 - val_accuracy: 0.8207
# Epoch 15/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5087 - accuracy: 0.8273 - val_loss: 0.5159 - val_accuracy: 0.8225
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5098 - accuracy: 0.8263 - val_loss: 0.5195 - val_accuracy: 0.8211
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5045 - accuracy: 0.8282 - val_loss: 0.5123 - val_accuracy: 0.8188
# Epoch 18/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4949 - accuracy: 0.8285 - val_loss: 0.5159 - val_accuracy: 0.8130
# Epoch 19/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4959 - accuracy: 0.8298 - val_loss: 0.5136 - val_accuracy: 0.8298
# Epoch 20/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5046 - accuracy: 0.8262 - val_loss: 0.5149 - val_accuracy: 0.8211

# %%
# Train the model 2
history2 = model2.fit(trainX, trainY_cat,
           epochs = epochs,
           batch_size = batch_size,
           validation_split = 0.2)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.9291 - accuracy: 0.6955 - val_loss: 0.6103 - val_accuracy: 0.7865
# Epoch 2/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.5720 - accuracy: 0.7936 - val_loss: 0.5491 - val_accuracy: 0.8036
# Epoch 3/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.5179 - accuracy: 0.8147 - val_loss: 0.5080 - val_accuracy: 0.8184
# Epoch 4/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.4869 - accuracy: 0.8259 - val_loss: 0.5012 - val_accuracy: 0.8200
# Epoch 5/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.4620 - accuracy: 0.8360 - val_loss: 0.4725 - val_accuracy: 0.8307
# Epoch 6/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.4436 - accuracy: 0.8432 - val_loss: 0.4986 - val_accuracy: 0.8128
# Epoch 7/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.4278 - accuracy: 0.8488 - val_loss: 0.4256 - val_accuracy: 0.8482
# Epoch 8/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.4123 - accuracy: 0.8545 - val_loss: 0.4170 - val_accuracy: 0.8543
# Epoch 9/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3976 - accuracy: 0.8604 - val_loss: 0.4124 - val_accuracy: 0.8505
# Epoch 10/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3863 - accuracy: 0.8640 - val_loss: 0.4066 - val_accuracy: 0.8579
# Epoch 11/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3768 - accuracy: 0.8679 - val_loss: 0.3877 - val_accuracy: 0.8602
# Epoch 12/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3655 - accuracy: 0.8701 - val_loss: 0.3936 - val_accuracy: 0.8611
# Epoch 13/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3565 - accuracy: 0.8731 - val_loss: 0.3949 - val_accuracy: 0.8603
# Epoch 14/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3479 - accuracy: 0.8776 - val_loss: 0.3550 - val_accuracy: 0.8727
# Epoch 15/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3402 - accuracy: 0.8802 - val_loss: 0.3472 - val_accuracy: 0.8774
# Epoch 16/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3329 - accuracy: 0.8821 - val_loss: 0.3400 - val_accuracy: 0.8783
# Epoch 17/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3252 - accuracy: 0.8838 - val_loss: 0.3689 - val_accuracy: 0.8717
# Epoch 18/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3199 - accuracy: 0.8863 - val_loss: 0.3354 - val_accuracy: 0.8798
# Epoch 19/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3134 - accuracy: 0.8882 - val_loss: 0.3282 - val_accuracy: 0.8835
# Epoch 20/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3091 - accuracy: 0.8903 - val_loss: 0.3248 - val_accuracy: 0.8859

# %%
# Train the model 3
history3 = model3.fit(trainX, trainY_cat,
           epochs = epochs,
           batch_size = batch_size,
           validation_split = 0.2)

# %% [markdown]
# ## **3. EVALUATE THE RESULTS**

# %%
model1.evaluate(testX, testY_cat)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5399 - accuracy: 0.8142
# [0.539932131767273, 0.8141999840736389]

# %%
plot_acc(history1)
plot_loss(history1)

# %%
model2.evaluate(testX, testY_cat)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3425 - accuracy: 0.8788
# [0.3425488770008087, 0.8787999749183655]

# %%
plot_acc(history2)
plot_loss(history2)
