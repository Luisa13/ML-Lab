# %% [markdown]
# # **UNDERSTANDING K-MEANS**
# The K-Means it's an unsupervised learning algorithm used for clustering. Since is an unsupervised, hence there is no target labels. This algorithm groups the similar clusters together.

# %%
# EDA
import numpy as np
import matplotlib.pyplot as plt
# The model
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %% [markdown]
# ## **1. Data Loading**

# %% [markdown]
# ## **2. Data Explore**

# %% [markdown]
# ## **3. The Model**

# %% [markdown]
# ### **3.1 Evaluate & Prediction**

# %% [markdown]
# *RESOURCES*
# * [Clustering data - KMeans](https://pub.towardsai.net/clustering-custom-data-using-the-k-means-algorithm-python-6a243308034a)
