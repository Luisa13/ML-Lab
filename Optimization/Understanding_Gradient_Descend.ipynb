# %% [markdown]
# # **UNDERSTANDING GRADIEND DESCEND**

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## **1. LOADING DATA**

# %% [markdown]
# _REFERENCES_
#
# * [Gradient Descent for Machine Learning](https://pub.towardsai.net/gradient-descent-algorithm-for-machine-learning-python-tutorial-ml-9ded189ec556)
