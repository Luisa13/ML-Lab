# %% [markdown]
# # **SIMPLE NEURAL NETWORK LAB**
# With this notebook we are going to explore the basics about the hyper parameter tuning in a simple neural network with keras and tensowflow. To do so, we will use the fashion MNIST from keras that can be explored and get more info [here](https://github.com/zalandoresearch/fashion-mnist).
#
# So here, we are going to cover
# * Basic hyper parameter tuning for a neural network
# * Overfitting study case
# * How to improve a basic model

# %%
# General use
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Machine Learning
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# %% [markdown]
# Let's define some methods that will be useful later when we present the results

# %%
def plot_acc(history, title="Model Accuracy"):
    '''
    Plot the accuracy per epoch got in the training
    '''
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(title)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
    
def plot_loss(history, title="Model Loss"):
  '''
  Plot the loss per epoch got in the training
  '''
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title(title)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()
    
def plot_compare_losses(history1, history2, name1="Red 1",
                        name2="Red 2", title="Graph title"):
  '''
  Compares two losses from two different trainings with name1 and name2
  '''
  plt.plot(history1.history['loss'], color="green")
  plt.plot(history1.history['val_loss'], 'r--', color="green")
  plt.plot(history2.history['loss'], color="blue")
  plt.plot(history2.history['val_loss'], 'r--', color="blue")
  plt.title(title)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train ' + name1, 'Val ' + name1, 
                'Train ' + name2, 'Val ' + name2],
               loc='upper right')
  plt.show()
    
def plot_compare_accs(history1, history2, name1="Red 1",
                      name2="Red 2", title="Graph title"):
  '''
  Compares two accuracies from two different trainings with name1 and nam2
  '''
  plt.plot(history1.history['acc'], color="green")
  plt.plot(history1.history['val_accuracy'], 'r--', color="green")
  plt.plot(history2.history['accuracy'], color="blue")
  plt.plot(history2.history['val_accuracy'], 'r--', color="blue")
  plt.title(title)
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train ' + name1, 'Val ' + name1, 
                'Train ' + name2, 'Val ' + name2], 
               loc='lower right')
  plt.show()


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='MATRIZ CONFUSIÓN',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    Credits to Keras
    """
    plt.figure(figsize = (10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Observación')
    plt.xlabel('Predicción')

# %% [markdown]
# ## **1. LOAD DATASET**
# We can download such dataset directly from [keras](https://www.kaggle.com/zalando-research/fashionmnist), and split right away in training and test.

# %%
# We load the data directly from keras
(trainX, trainY), (testX, testY) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# # 1.1. Data Exploration
# So we have a dataset with 60000 images where each one has a dimension of 28x28. In the dataset we got 10000 items (images) with the same shape as in the training dataset.
#
# Alongside, and if we have a look to the dataset documentation previously mentioned we can see it's possible to distiguish between a certain amount of fashion items, and **that's what defines a classification problem** (which surprise, is our case).
# In classification, the goals is being able to identify which class belongs the input to.
#
# To be able to manage our data correctly we turn the class-arrayf (*Y*) into categorical.

# %%
# We explore the data we got
print("Training: {}\nTest: {}".format(trainX.shape, testX.shape))

# Get also the clases, encoding it to categorical
trainY_cat = to_categorical(trainY)
testY_cat = to_categorical(testY)
print("\nClasses: {}".format(trainY_cat.shape))
# Out:
# Training: (60000, 28, 28)
# Test: (10000, 28, 28)
#
# Classes: (60000, 10)

# %% [markdown]
# and map it accordingly for a better representation
#
#
# ![Captura.JPG](data:image/jpeg;base64,...)

# %%
# We map the clases for a better representation
class_names = {
0: 	'T-shirt/top',
1:	'Trouser',
2:	'Pullover',
3:	'Dress',
4: 	'Coat',
5:	'Sandal',
6:	'Shirt',
7:	'Sneaker',
8:	'Bag',
9:	'Ankle boot'
}

# %% [markdown]
# # 1.2 Data Preview

# %%
def plot_item(item):
  '''
  Displays just one item from the dataset
  '''
  plt.figure()
  plt.imshow(item)
  plt.show()


def plot_sample(size, dim = 5):
  '''
  Display a sub dataset from the original one
  '''
  plt.figure(figsize = (dim, dim))
  cols = size/dim
  for i in range (size):
    plt.subplot(dim, cols, i+1)
    plt.imshow(trainX[i])
  plt.show()


def plot_distribution():
  '''
  Plots the distribution of every class
  '''
  plt.figure(figsize = (10,6))
  fashion = list(class_names.values())
  # We user the raw data (no categorical) to count them up
  unique, count = np.unique(trainY, return_counts = True)

  plt.bar(fashion, count)
  plt.xlabel('fashion name')
  plt.ylabel('number')
  plt.show()

# %%
# Visualize just one item
plot_item(trainX[6])

# %%
# Visualize a subset from the original dataset spcifying the number of item
plot_sample(20)

# %%
# Let's see the distribution of the data
plot_distribution()

# %% [markdown]
# ##**2. THE MODEL**
# # 2.1 Define the architectures

# %% [markdown]
# ### 2.1.1 Model 1

# %%
# Define model n1
n_classes = trainY_cat.shape[1]
model1 = Sequential()
model1.add(Flatten(input_shape =(28,28) ))
model1.add(Dense(128, activation='sigmoid'))
model1.add(Dense (64, activation='sigmoid'))
model1.add(Dense(n_classes, activation='softmax'))

# %% [markdown]
# ### 2.1.2 Model 2

# %%
# Rehape the training data to have only one channel
trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
testX = testX.reshape((testX.shape[0], 28, 28, 1))

# Make it easier te convergence 
trainX = trainX/255
testX = testX/255

# %%
# Define model n2
model2 = Sequential()
model2.add(Conv2D(32, (3,3), activation='relu', kernel_initializer='he_uniform', input_shape= trainX[1].shape ))
model2.add(MaxPooling2D(2,2))
model2.add(Flatten())
model2.add(Dense (64, activation='relu'))
model2.add(Dense(n_classes, activation = 'softmax'))

# %% [markdown]
# ### 2.1.3 Model 3

# %%
# Define model n3
model3 = Sequential()
model3.add(Conv2D(32, (3,3), activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),
                  input_shape= trainX[1].shape ))
model3.add(MaxPooling2D(2,2))
model3.add(BatchNormalization())
model3.add(Flatten())
model3.add(Dense (64, activation='relu'))
model3.add(Dropout(0.25))
model3.add(Dense(n_classes, activation = 'softmax'))

# %% [markdown]
# # 2.2 Compilation
#
#
# > TODO: explain
# > * why categorical_crossentropy in loss
# > * why we are using sgd as optimizer

# %%
model1.compile(
    optimizer = 'sgd',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
model2.compile(
    optimizer = 'sgd',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
model3.compile(
    optimizer = 'sgd',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %% [markdown]
# ## **3. RUN AND EVALUATE**

# %% [markdown]
# # 3.1. Model 1
# ## 3.1.1  Fit Model 1
#
#
#
# > EXPLAIN:
# > this is the simplest but not the best accuracy.
# > Get the least overfitting though

# %%
# Define number of epochs and batch size
epochs = 20
batch_size = 64

# Train the model 1
history1 = model1.fit(trainX, trainY_cat,
           epochs = epochs,
           batch_size = batch_size,
           validation_split = 0.2)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 2s 3ms/step - loss: 1.8032 - accuracy: 0.5546 - val_loss: 1.3855 - val_accuracy: 0.6834
# Epoch 2/20
# 750/750 [==============================] - 2s 2ms/step - loss: 1.1490 - accuracy: 0.7154 - val_loss: 0.9670 - val_accuracy: 0.7454
# Epoch 3/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.8695 - accuracy: 0.7581 - val_loss: 0.7916 - val_accuracy: 0.7663
# Epoch 4/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.7388 - accuracy: 0.7771 - val_loss: 0.6969 - val_accuracy: 0.7887
# Epoch 5/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.6648 - accuracy: 0.7917 - val_loss: 0.6413 - val_accuracy: 0.7930
# Epoch 6/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.6122 - accuracy: 0.8026 - val_loss: 0.5993 - val_accuracy: 0.7977
# Epoch 7/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5799 - accuracy: 0.8092 - val_loss: 0.5771 - val_accuracy: 0.8087
# Epoch 8/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5604 - accuracy: 0.8130 - val_loss: 0.5508 - val_accuracy: 0.8136
# Epoch 9/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.8167 - val_loss: 0.5358 - val_accuracy: 0.8222
# Epoch 10/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.8198 - val_loss: 0.5444 - val_accuracy: 0.8111
# Epoch 11/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5250 - accuracy: 0.8237 - val_loss: 0.5288 - val_accuracy: 0.8192
# Epoch 12/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5204 - accuracy: 0.8233 - val_loss: 0.5229 - val_accuracy: 0.8257
# Epoch 13/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5140 - accuracy: 0.8238 - val_loss: 0.5168 - val_accuracy: 0.8189
# Epoch 14/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5103 - accuracy: 0.8245 - val_loss: 0.5269 - val_accuracy: 0.8207
# Epoch 15/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5087 - accuracy: 0.8273 - val_loss: 0.5159 - val_accuracy: 0.8225
# Epoch 16/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5098 - accuracy: 0.8263 - val_loss: 0.5195 - val_accuracy: 0.8211
# Epoch 17/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5045 - accuracy: 0.8282 - val_loss: 0.5123 - val_accuracy: 0.8188
# Epoch 18/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4949 - accuracy: 0.8285 - val_loss: 0.5159 - val_accuracy: 0.8130
# Epoch 19/20
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4959 - accuracy: 0.8298 - val_loss: 0.5136 - val_accuracy: 0.8298
# Epoch 20/20
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5046 - accuracy: 0.8262 - val_loss: 0.5149 - val_accuracy: 0.8211

# %% [markdown]
# ## 3.1.2 Evaluate

# %%
model1.evaluate(testX, testY_cat)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5399 - accuracy: 0.8142
# [0.539932131767273, 0.8141999840736389]

# %%
plot_acc(history1)
plot_loss(history1)

# %% [markdown]
# # 3.2 Model 2
# ## 3.2.1 Fit Model 2

# %%
# Define number of epochs and batch size
epochs = 20
batch_size = 64

# Train the model 2
history2 = model2.fit(trainX, trainY_cat,
           epochs = epochs,
           batch_size = batch_size,
           validation_split = 0.2)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 19s 26ms/step - loss: 0.6493 - accuracy: 0.7744 - val_loss: 0.5020 - val_accuracy: 0.8253
# Epoch 2/20
# 750/750 [==============================] - 19s 26ms/step - loss: 0.4631 - accuracy: 0.8370 - val_loss: 0.4557 - val_accuracy: 0.8402
# Epoch 3/20
# 750/750 [==============================] - 19s 26ms/step - loss: 0.4155 - accuracy: 0.8550 - val_loss: 0.4019 - val_accuracy: 0.8583
# Epoch 4/20
# 750/750 [==============================] - 19s 26ms/step - loss: 0.3875 - accuracy: 0.8636 - val_loss: 0.3739 - val_accuracy: 0.8684
# Epoch 5/20
# 750/750 [==============================] - 19s 26ms/step - loss: 0.3671 - accuracy: 0.8696 - val_loss: 0.3966 - val_accuracy: 0.8556
# Epoch 6/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.3517 - accuracy: 0.8771 - val_loss: 0.3527 - val_accuracy: 0.8758
# Epoch 7/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.3372 - accuracy: 0.8798 - val_loss: 0.3678 - val_accuracy: 0.8673
# Epoch 8/20
# 750/750 [==============================] - 19s 26ms/step - loss: 0.3265 - accuracy: 0.8842 - val_loss: 0.3367 - val_accuracy: 0.8813
# Epoch 9/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.3173 - accuracy: 0.8879 - val_loss: 0.3314 - val_accuracy: 0.8835
# Epoch 10/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.3056 - accuracy: 0.8920 - val_loss: 0.3370 - val_accuracy: 0.8784
# Epoch 11/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2989 - accuracy: 0.8941 - val_loss: 0.3135 - val_accuracy: 0.8870
# Epoch 12/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2913 - accuracy: 0.8962 - val_loss: 0.3135 - val_accuracy: 0.8883
# Epoch 13/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2834 - accuracy: 0.8977 - val_loss: 0.3082 - val_accuracy: 0.8904
# Epoch 14/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2770 - accuracy: 0.9004 - val_loss: 0.2974 - val_accuracy: 0.8926
# Epoch 15/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2719 - accuracy: 0.9015 - val_loss: 0.3097 - val_accuracy: 0.8916
# Epoch 16/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2656 - accuracy: 0.9048 - val_loss: 0.2939 - val_accuracy: 0.8990
# Epoch 17/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2599 - accuracy: 0.9076 - val_loss: 0.2917 - val_accuracy: 0.8974
# Epoch 18/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2552 - accuracy: 0.9083 - val_loss: 0.2906 - val_accuracy: 0.8963
# Epoch 19/20
# 750/750 [==============================] - 20s 27ms/step - loss: 0.2500 - accuracy: 0.9105 - val_loss: 0.2809 - val_accuracy: 0.9007
# Epoch 20/20
# 750/750 [==============================] - 20s 26ms/step - loss: 0.2465 - accuracy: 0.9111 - val_loss: 0.2737 - val_accuracy: 0.9035

# %% [markdown]
# ## 3.2.2 Evaluate

# %%
model2.evaluate(testX, testY_cat)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2904 - accuracy: 0.8927
# [0.29041916131973267, 0.8927000164985657]

# %%
plot_acc(history2)
plot_loss(history2)

# %%
# Train the model 3
callback = [EarlyStopping(monitor='val_loss', patience=5)]

history3 = model3.fit(trainX, trainY_cat,
           epochs = epochs,
           batch_size = batch_size,
           callbacks = callback,
           validation_split = 0.2)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.5619 - accuracy: 0.8127 - val_loss: 0.4041 - val_accuracy: 0.8584
# Epoch 2/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.3971 - accuracy: 0.8671 - val_loss: 0.3609 - val_accuracy: 0.8731
# Epoch 3/20
# 750/750 [==============================] - 23s 30ms/step - loss: 0.3508 - accuracy: 0.8819 - val_loss: 0.3131 - val_accuracy: 0.8916
# Epoch 4/20
# 750/750 [==============================] - 23s 30ms/step - loss: 0.3253 - accuracy: 0.8899 - val_loss: 0.3001 - val_accuracy: 0.8963
# Epoch 5/20
# 750/750 [==============================] - 23s 30ms/step - loss: 0.3048 - accuracy: 0.8973 - val_loss: 0.2941 - val_accuracy: 0.8975
# Epoch 6/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2907 - accuracy: 0.9010 - val_loss: 0.2995 - val_accuracy: 0.8957
# Epoch 7/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2767 - accuracy: 0.9071 - val_loss: 0.2791 - val_accuracy: 0.9029
# Epoch 8/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2669 - accuracy: 0.9095 - val_loss: 0.2780 - val_accuracy: 0.9047
# Epoch 9/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2559 - accuracy: 0.9137 - val_loss: 0.2843 - val_accuracy: 0.8988
# Epoch 10/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2467 - accuracy: 0.9187 - val_loss: 0.2689 - val_accuracy: 0.9062
# Epoch 11/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2376 - accuracy: 0.9204 - val_loss: 0.2679 - val_accuracy: 0.9077
# Epoch 12/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2329 - accuracy: 0.9235 - val_loss: 0.2675 - val_accuracy: 0.9082
# Epoch 13/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2245 - accuracy: 0.9250 - val_loss: 0.2736 - val_accuracy: 0.9077
# Epoch 14/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.2172 - accuracy: 0.9282 - val_loss: 0.3170 - val_accuracy: 0.8888
# Epoch 15/20
# 750/750 [==============================] - 23s 30ms/step - loss: 0.2110 - accuracy: 0.9295 - val_loss: 0.2630 - val_accuracy: 0.9113
# Epoch 16/20
# 750/750 [==============================] - 23s 30ms/step - loss: 0.2038 - accuracy: 0.9338 - val_loss: 0.2673 - val_accuracy: 0.9087
# Epoch 17/20
# 750/750 [==============================] - 23s 30ms/step - loss: 0.2006 - accuracy: 0.9344 - val_loss: 0.2670 - val_accuracy: 0.9124
# Epoch 18/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.1936 - accuracy: 0.9375 - val_loss: 0.2579 - val_accuracy: 0.9126
# Epoch 19/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.1890 - accuracy: 0.9384 - val_loss: 0.2586 - val_accuracy: 0.9118
# Epoch 20/20
# 750/750 [==============================] - 23s 31ms/step - loss: 0.1845 - accuracy: 0.9398 - val_loss: 0.2686 - val_accuracy: 0.9110

# %%
model3.evaluate(testX, testY_cat)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2859 - accuracy: 0.9058
# [0.2859379053115845, 0.9057999849319458]

# %%
plot_acc(history3)
plot_loss(history3)
